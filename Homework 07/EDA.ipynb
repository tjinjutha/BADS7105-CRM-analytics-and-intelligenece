# %% [markdown]
# #### import

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# #### โหลด data

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
data_path= "/content/drive/MyDrive/Colab Notebooks/CRM/Homework 07/Customer Preference Survey (การตอบกลับ).xlsx"
data = pd.read_excel(data_path,engine='openpyxl')

# %%
data.head()
# Out:
#                ประทับเวลา  จักรยานเสือภูเขา  ...  Software ถูกลิขสิทธิ์  ครีมกันแดด
# 0 2021-03-20 11:53:44.586                 0  ...                      1           1
# 1 2021-03-20 11:54:00.984                 0  ...                      0           1
# 2 2021-03-20 11:54:05.084                 1  ...                      1           1
# 3 2021-03-20 11:54:12.558                 0  ...                      0           1
# 4 2021-03-20 11:54:18.477                 0  ...                      1           1
#
# [5 rows x 62 columns]

# %%
data.tail()
# Out:
#                 ประทับเวลา  จักรยานเสือภูเขา  ...  Software ถูกลิขสิทธิ์  ครีมกันแดด
# 40 2021-03-20 12:03:24.608                 0  ...                      0           1
# 41 2021-03-20 12:03:52.592                 1  ...                      1           1
# 42 2021-03-20 12:04:19.003                 0  ...                      1           1
# 43 2021-04-05 16:13:52.286                 0  ...                      1           1
# 44 2021-04-16 16:29:59.099                 0  ...                      1           1
#
# [5 rows x 62 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45 entries, 0 to 44
# Data columns (total 62 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   ประทับเวลา                       45 non-null     datetime64[ns]
#  1   จักรยานเสือภูเขา                 45 non-null     int64
#  2   คอลลาเจน                         45 non-null     int64
#  3   Brownie อวกาศ                    45 non-null     int64
#  4   แม่โขง                           45 non-null     int64
#  5   Botox                            45 non-null     int64
#  6   กัญชา                            45 non-null     int64
#  7   กัญชง                            45 non-null     int64
#  8   เครื่องวัดความดัน                45 non-null     int64
#  9   หลอดไฟเปลี่ยนสีได้               45 non-null     int64
#  10  คอร์ส bikini wax                 45 non-null     int64
#  11  เก้าอี้นวดไฟฟ้า                  45 non-null     int64
# ...

# %% [markdown]
# #### drop

# %%
data.drop(columns=['เครื่องย่อยเศษอาหาร.1', 'Botox',"ประทับเวลา"],inplace = True)

# %% [markdown]
# #### จำนวน product

# %%
len(data.columns)
# Out:
# 59

# %%
data.columns
# Out:
# Index(['จักรยานเสือภูเขา', 'คอลลาเจน', 'Brownie อวกาศ', 'แม่โขง', 'กัญชา',
#        'กัญชง', 'เครื่องวัดความดัน', 'หลอดไฟเปลี่ยนสีได้', 'คอร์ส bikini wax',
#        'เก้าอี้นวดไฟฟ้า', 'ต้นไม้ประดับห้อง', 'หมอนข้าง', 'ตาชั่ง ',
#        'คอร์สโบท็อกกราม', 'แสงโสม', 'กะหรี่(ปั๊บ)', 'Lego',
#        'แฟน ที่แปลว่าพัดลม', 'ยาดอง', 'ชุดนอนไม่ได้นอน',
#        'ที่ยกน้ำหนัก (Dumbell)', 'เครื่องดูดฝุ่นอัตโนมัติ (robot)',
#        'เนื้อวากิล', 'หมูแดดเดียว', 'drone', 'เครื่องย่อยเศษอาหาร',
#        'เสื้อซีทรู', 'ไพ่ยิปซี', 'เนื้อย่าง', 'เครื่องทำลายเอกสาร', 'กระเป๋า',
#        'ชาบู', 'Surfskate', 'Board game', 'ชุดน้องหมา', 'Omakase',
#        'เม็ดมะม่วงหิมพานต์', 'ไฟอัจฉริยะ', 'บัตตาเลี่ยนที่ตัดผม',
#        'ไดร์เป่าผม Dyson', 'แผ่นเสียง', 'กรรไกรตัดขนจมูก', 'PS5',
#        'เครื่องตรวจน้ำตาลในเลือด', 'โรตี', 'กะปิดอง', 'น้องหมา',
#        'แพ็คเกจไทยเที่ยวไทย', 'เกมส์ FIFA Online', 'มะม่วงเบา',
#        'ห้องน้ำแมวอัตโนมัติ', 'กระเป๋า chanel', 'ข้าวขาหมูคากิคาจักออนไลน์',
# ...

# %% [markdown]
# ### Most common popolar product
# ครีมกันแดด                         45.0
# กระเป๋า                            45.0
# ชาบู                               45.0
# โรตี                               44.0
# กะหรี่(ปั๊บ)                       43.0
# เม็ดมะม่วงหิมพานต์                 41.0

# %%
data.sum(axis=0).sort_values(ascending=False)
# Out:
# ครีมกันแดด                         45.0
# กระเป๋า                            45.0
# ชาบู                               45.0
# โรตี                               44.0
# กะหรี่(ปั๊บ)                       43.0
# เม็ดมะม่วงหิมพานต์                 41.0
# หมอนข้าง                           39.0
# แฟน ที่แปลว่าพัดลม                 37.0
# หมูแดดเดียว                        37.0
# Software ถูกลิขสิทธิ์              36.0
# เนื้อย่าง                          33.0
# ต้นไม้ประดับห้อง                   32.0
# เนื้อวากิล                         31.0
# น้ำส้มดีโด้                        30.0
# ตาชั่ง                             30.0
# Lego                               29.0
# Board game                         28.0
# ที่ยกน้ำหนัก (Dumbell)             27.0
# คอลลาเจน                           25.0
# เครื่องดูดฝุ่นอัตโนมัติ (robot)    24.0
# แพ็คเกจไทยเที่ยวไทย                21.0
# กรรไกรตัดขนจมูก                    18.0
# หมอนสุขภาพสำหรับคนนอนไม่หลับ       18.0
# ...

# %%
most_popular = data.sum(axis=0).sort_values(ascending=False)

# %% [markdown]
# #### Un popular item
# เครื่องย่อยเศษอาหาร                 2.0
# PS5                                 2.0
# Surfskate                           3.0
# ห้องน้ำแมวอัตโนมัติ                 3.0
# อาหารแมวคลีนเพื่อสุขภาพลดหุ่น       4.0
# กัญชง                               4.0
# คอร์ส bikini wax                    4.0
# Brownie อวกาศ                       5.

# %%
data.sum(axis=0).sort_values(ascending=True)
# Out:
# เครื่องย่อยเศษอาหาร                 2.0
# PS5                                 2.0
# Surfskate                           3.0
# ห้องน้ำแมวอัตโนมัติ                 3.0
# อาหารแมวคลีนเพื่อสุขภาพลดหุ่น       4.0
# กัญชง                               4.0
# คอร์ส bikini wax                    4.0
# Brownie อวกาศ                       5.0
# ไดร์เป่าผม Dyson                    5.0
# กระเป๋า chanel                      5.0
# คอร์สโบท็อกกราม                     5.0
# drone                               6.0
# เก้าอี้นวดไฟฟ้า                     6.0
# ข้าวขาหมูคากิคาจักออนไลน์           6.0
# เกมส์ FIFA Online                   6.0
# ชุดนอนไม่ได้นอน                     7.0
# เครื่องทำลายเอกสาร                  7.0
# ถั่งเช่า                            8.0
# กัญชา                               8.0
# บัตตาเลี่ยนที่ตัดผม                 8.0
# กะปิดอง                             9.0
# แผ่นเสียง                           9.0
# เครื่องตรวจน้ำตาลในเลือด           10.0
# ...

# %% [markdown]
# #### Common stat

# %%
data.describe().T.sort_values('mean', ascending=False)
# Out:
#                                  count      mean       std  ...  50%  75%  max
# ครีมกันแดด                        45.0  1.000000  0.000000  ...  1.0  1.0  1.0
# กระเป๋า                           45.0  1.000000  0.000000  ...  1.0  1.0  1.0
# ชาบู                              45.0  1.000000  0.000000  ...  1.0  1.0  1.0
# โรตี                              45.0  0.977778  0.149071  ...  1.0  1.0  1.0
# กะหรี่(ปั๊บ)                      45.0  0.955556  0.208409  ...  1.0  1.0  1.0
# เม็ดมะม่วงหิมพานต์                45.0  0.911111  0.287799  ...  1.0  1.0  1.0
# หมอนข้าง                          45.0  0.866667  0.343776  ...  1.0  1.0  1.0
# หมูแดดเดียว                       45.0  0.822222  0.386646  ...  1.0  1.0  1.0
# แฟน ที่แปลว่าพัดลม                45.0  0.822222  0.386646  ...  1.0  1.0  1.0
# Software ถูกลิขสิทธิ์             45.0  0.800000  0.404520  ...  1.0  1.0  1.0
# เนื้อย่าง                         45.0  0.733333  0.447214  ...  1.0  1.0  1.0
# ...

# %%
data.to_csv("dataset.csv")

# %%
# !wget -q https://github.com/Phonbopit/sarabun-webfont/raw/master/fonts/thsarabunnew-webfont.ttf

# %%
# !pip install -U --pre matplotlib  
import matplotlib as mpl
mpl.font_manager.fontManager.addfont('thsarabunnew-webfont.ttf')
mpl.rc('font', family='TH Sarabun New')

# %% [markdown]
# #### Most popular plot

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(12,12))
most_popular.head(30).plot(kind = "bar")
