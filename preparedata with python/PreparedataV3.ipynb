# %%
import pandas as pd

# %%
consump = pd.read_excel("consumption.xlsx",engine='openpyxl')

# %%
consump
# Out:
#     อาหารญี่ปุ่น  อาหารจึน  อาหารไทย  อาหารอีสาน  อาหารสุขภาพ  บุฟเฟต์  \
# 0              2         1         5           4            5        2
# 1              4         1         5           4            4        2
# 2              4         1         5           1            1        3
# 3              3         0         5           2            0        3
# 4              2         3         4           4            5        1
# ..           ...       ...       ...         ...          ...      ...
# 58             1         1         5           2            1        1
# 59             1         1         5           2            2        2
# 60             3         1         5           4            4        1
# 61             2         1         2           4            3        3
# 62             2         3         5           4            5        3
#
#     ชาบูชาบู  ปิ้งย่าง  เหล้าเบียร์  เสื้อผ้าแฟชั่น  ...  \
# ...

# %%
 consum_col = consump.columns

# %%
len(consump.columns)
# Out:
# 33

# %%
col_name = []
for i in range(30):
    col_name.append("บริโภค"+ consump.columns[i])

# %%
col_name
# Out:
# ['บริโภคอาหารญี่ปุ่น',
#  'บริโภคอาหารจึน',
#  'บริโภคอาหารไทย',
#  'บริโภคอาหารอีสาน',
#  'บริโภคอาหารสุขภาพ',
#  'บริโภคบุฟเฟต์',
#  'บริโภคชาบูชาบู',
#  'บริโภคปิ้งย่าง',
#  'บริโภคเหล้าเบียร์',
#  'บริโภคเสื้อผ้าแฟชั่น',
#  'บริโภคแต่งหน้า',
#  'บริโภคskincare บำรุงผิว',
#  'บริโภคการออกกำลังกาย',
#  'บริโภคการเล่นเกมส์',
#  'บริโภคการท่องเที่ยว',
#  'บริโภคการอ่านหนังสือ',
#  'บริโภคการอ่านบทความ Online',
#  'บริโภคการเรียน e-learning',
#  'บริโภคดู Series',
#  'บริโภคดูหนัง',
#  'บริโภคดู Youtube',
#  'บริโภคดู Netflix',
#  'บริโภคContent ด้านบันเทิง',
#  'บริโภคContent เกี่่ยวกับเกมส์',
#  'บริโภคContent เกี่ยวกับการ review ร้านอาหาร',
#  'บริโภคContent เกี่ยวกับการท่องเที่ยว',
#  'บริโภคContent เกี่ยวกับการแต่งบ้าน',
#  'บริโภคContent เกี่ยวกับการโทรทัศน์',
#  'บริโภคContent เกี่ยวกับละคร',
#  'บริโภคContent เกี่ยวกับการเมือง']

# %%
col_eng = [
    'Japan Food',
    'China Food',
    "Thai Food",
    "E-San Food",
    "Clean Food",
    "Buffet",
    "Shabu",
    "Yakiniku",
    "Drinking",
    "Fashion",
    "Makeup",
    "Skincare",
    "Exercise",
    "Play game",
    "Travel",
    "Reading Book",
    "Online reading",
    "E-Learning",
    "Watch Series",
    "Watch Movies",
    "Watch Netflix",
    "Content Entertainment",
    "Content Game",
    "Content Food",
    "Content Home",
    "Content TV",
    "Content Series",
    "Content Politic"
]

# %%
consump.rename(columns= dict(zip(consum_col,col_eng)),inplace = True)

# %%
consump
# Out:
#     Japan Food  China Food  Thai Food  E-San Food  Clean Food  Buffet  Shabu  \
# 0            2           1          5           4           5       2      2
# 1            4           1          5           4           4       2      2
# 2            4           1          5           1           1       3      3
# 3            3           0          5           2           0       3      3
# 4            2           3          4           4           5       1      1
# ..         ...         ...        ...         ...         ...     ...    ...
# 58           1           1          5           2           1       1      1
# 59           1           1          5           2           2       2      2
# 60           3           1          5           4           4       1      1
# 61           2           1          2           4           3       3      3
# 62           2           3          5           4           5       3      3
#
# ...

# %%
consump.to_excel("consump.xlsx")

# %%
interest = pd.read_excel("interest.xlsx",engine='openpyxl')

# %%
interest_col = interest.columns
interest_col
# Out:
# Index(['อาหารญี่ปุ่น', 'อาหารจึน', 'อาหารไทย', 'อาหารอีสาน', 'อาหารสุขภาพ',
#        'บุฟเฟต์', 'ชาบูชาบู', 'ปิ้งย่าง', 'เหล้าเบียร์', 'เสื้อผ้าแฟชั่น',
#        'แต่งหน้า', 'skincare บำรุงผิว', 'การออกกำลังกาย', 'การเล่นเกมส์',
#        'การท่องเที่ยว', 'การอ่านหนังสือ', 'การอ่านบทความ Online',
#        'การเรียน e-learning', 'ดู Series', 'ดูหนัง', 'ดู Youtube',
#        'ดู Netflix', 'Content ด้านบันเทิง', 'Content เกี่่ยวกับเกมส์',
#        'Content เกี่ยวกับการ review ร้านอาหาร',
#        'Content เกี่ยวกับการท่องเที่ยว', 'Content เกี่ยวกับการแต่งบ้าน',
#        'Content เกี่ยวกับการโทรทัศน์', 'Content เกี่ยวกับละคร',
#        'Content เกี่ยวกับการเมือง', 'Other_comment', 'อายุ', 'เพศ'],
#       dtype='object')

# %%
interest.rename(columns= dict(zip(interest_col,col_eng)),inplace = True)

# %%
interest
# Out:
#     Japan Food  China Food  Thai Food  E-San Food  Clean Food  Buffet  Shabu  \
# 0            4           4          6           5           4       4      4
# 1            5           3          6           5           4       5      6
# 2            6           3          5           4           3       6      6
# 3            4           3          3           3           4       4      4
# 4            5           4          4           4           6       3      3
# ..         ...         ...        ...         ...         ...     ...    ...
# 58           4           6          6           6           6       3      3
# 59           5           4          5           4           6       5      6
# 60           4           3          5           5           4       1      3
# 61           6           4          5           5           5       6      6
# 62           4           3          3           3           5       3      3
#
# ...

# %%
consump.to_excel("inter.xlsx")
