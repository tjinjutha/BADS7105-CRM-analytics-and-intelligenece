# %%
import pandas as pd

# %%
df = pd.read_excel("dataset.xlsx",engine='openpyxl')

# %%
df.head()
# Out:
#            Category  Score  ID                     Comment      Type
# 0  สนใจอาหารญี่ปุ่น      2   1            กีฬา UFC, Soccer  Interest
# 1  สนใจอาหารญี่ปุ่น      4   2  กีฬา สัตว์เลี้ยง เทคโนโลยี  Interest
# 2  สนใจอาหารญี่ปุ่น      4   3                           -  Interest
# 3  สนใจอาหารญี่ปุ่น      3   4            โหราศาสตร์,ดูดวง  Interest
# 4  สนใจอาหารญี่ปุ่น      2   5                 สัตว์เลี้ยง  Interest

# %%
df.Category.unique()
# Out:
# array(['สนใจอาหารญี่ปุ่น', 'สนใจอาหารจึน', 'สนใจอาหารไทย',
#        'สนใจอาหารอีสาน', 'สนใจอาหารสุขภาพ', 'สนใจบุฟเฟต์', 'สนใจชาบูชาบู',
#        'สนใจปิ้งย่าง', 'สนใจเหล้าเบียร์', 'สนใจเสื้อผ้าแฟชั่น',
#        'สนใจแต่งหน้า', 'สนใจskincare บำรุงผิว', 'สนใจการออกกำลังกาย',
#        'สนใจการเล่นเกมส์', 'สนใจการท่องเที่ยว', 'สนใจการอ่านหนังสือ',
#        'สนใจการอ่านบทความ Online', 'สนใจการเรียน e-learning',
#        'สนใจดู Series', 'สนใจดูหนัง', 'สนใจดู Youtube', 'สนใจดู Netflix',
#        'สนใจContent ด้านบันเทิง', 'สนใจContent เกี่่ยวกับเกมส์',
#        'สนใจContent เกี่ยวกับการ review ร้านอาหาร',
#        'สนใจContent เกี่ยวกับการท่องเที่ยว',
#        'สนใจContent เกี่ยวกับการแต่งบ้าน',
#        'สนใจContent เกี่ยวกับการโทรทัศน์', 'สนใจContent เกี่ยวกับละคร',
#        'สนใจContent เกี่ยวกับการเมือง', 'บริโภคอาหารญี่ปุ่น',
#        'บริโภคอาหารจึน', 'บริโภคอาหารไทย', 'บริโภคอาหารอีสาน',
#        'บริโภคอาหารสุขภาพ', 'บริโภคบุฟเฟต์', 'บริโภคชาบูชาบู',
# ...

# %%
interest = ['สนใจอาหารญี่ปุ่น', 'สนใจอาหารจึน', 'สนใจอาหารไทย',
       'สนใจอาหารอีสาน', 'สนใจอาหารสุขภาพ', 'สนใจบุฟเฟต์', 'สนใจชาบูชาบู',
       'สนใจปิ้งย่าง', 'สนใจเหล้าเบียร์', 'สนใจเสื้อผ้าแฟชั่น',
       'สนใจแต่งหน้า', 'สนใจskincare บำรุงผิว', 'สนใจการออกกำลังกาย',
       'สนใจการเล่นเกมส์', 'สนใจการท่องเที่ยว', 'สนใจการอ่านหนังสือ',
       'สนใจการอ่านบทความ Online', 'สนใจการเรียน e-learning',
       'สนใจดู Series', 'สนใจดูหนัง', 'สนใจดู Youtube', 'สนใจดู Netflix',
       'สนใจContent ด้านบันเทิง', 'สนใจContent เกี่่ยวกับเกมส์',
       'สนใจContent เกี่ยวกับการ review ร้านอาหาร',
       'สนใจContent เกี่ยวกับการท่องเที่ยว',
       'สนใจContent เกี่ยวกับการแต่งบ้าน',
       'สนใจContent เกี่ยวกับการโทรทัศน์', 'สนใจContent เกี่ยวกับละคร',
       'สนใจContent เกี่ยวกับการเมือง']

# %%
consump = ['บริโภคอาหารญี่ปุ่น',
       'บริโภคอาหารจึน', 'บริโภคอาหารไทย', 'บริโภคอาหารอีสาน',
       'บริโภคอาหารสุขภาพ', 'บริโภคบุฟเฟต์', 'บริโภคชาบูชาบู',
       'บริโภคปิ้งย่าง', 'บริโภคเหล้าเบียร์', 'บริโภคเสื้อผ้าแฟชั่น',
       'บริโภคแต่งหน้า', 'บริโภคskincare บำรุงผิว',
       'บริโภคการออกกำลังกาย', 'บริโภคการเล่นเกมส์',
       'บริโภคการท่องเที่ยว', 'บริโภคการอ่านหนังสือ',
       'บริโภคการอ่านบทความ Online', 'บริโภคการเรียน e-learning',
       'บริโภคดู Series', 'บริโภคดูหนัง', 'บริโภคดู Youtube',
       'บริโภคดู Netflix', 'บริโภคContent ด้านบันเทิง',
       'บริโภคContent เกี่่ยวกับเกมส์',
       'บริโภคContent เกี่ยวกับการ review ร้านอาหาร',
       'บริโภคContent เกี่ยวกับการท่องเที่ยว',
       'บริโภคContent เกี่ยวกับการแต่งบ้าน',
       'บริโภคContent เกี่ยวกับการโทรทัศน์',
       'บริโภคContent เกี่ยวกับละคร', 'บริโภคContent เกี่ยวกับการเมือง']

# %%
intet_type = ["Interest" for i in interest]

# %%
df2 = pd.DataFrame(zip(interest,intet_type) , columns=["Category","Type"])

# %%
df2
# Out:
#                                      Category      Type
# 0                            สนใจอาหารญี่ปุ่น  Interest
# 1                                สนใจอาหารจึน  Interest
# 2                                สนใจอาหารไทย  Interest
# 3                              สนใจอาหารอีสาน  Interest
# 4                             สนใจอาหารสุขภาพ  Interest
# 5                                 สนใจบุฟเฟต์  Interest
# 6                                สนใจชาบูชาบู  Interest
# 7                                สนใจปิ้งย่าง  Interest
# 8                             สนใจเหล้าเบียร์  Interest
# 9                          สนใจเสื้อผ้าแฟชั่น  Interest
# 10                               สนใจแต่งหน้า  Interest
# 11                      สนใจskincare บำรุงผิว  Interest
# 12                         สนใจการออกกำลังกาย  Interest
# 13                           สนใจการเล่นเกมส์  Interest
# 14                          สนใจการท่องเที่ยว  Interest
# 15                         สนใจการอ่านหนังสือ  Interest
# ...

# %%
consump_type = ["Consumption" for i in consump]

# %%
df3 = pd.DataFrame(zip(consump,consump_type) , columns=["Category","Type"])

# %%
df3
# Out:
#                                        Category         Type
# 0                            บริโภคอาหารญี่ปุ่น  Consumption
# 1                                บริโภคอาหารจึน  Consumption
# 2                                บริโภคอาหารไทย  Consumption
# 3                              บริโภคอาหารอีสาน  Consumption
# 4                             บริโภคอาหารสุขภาพ  Consumption
# 5                                 บริโภคบุฟเฟต์  Consumption
# 6                                บริโภคชาบูชาบู  Consumption
# 7                                บริโภคปิ้งย่าง  Consumption
# 8                             บริโภคเหล้าเบียร์  Consumption
# 9                          บริโภคเสื้อผ้าแฟชั่น  Consumption
# 10                               บริโภคแต่งหน้า  Consumption
# 11                      บริโภคskincare บำรุงผิว  Consumption
# 12                         บริโภคการออกกำลังกาย  Consumption
# 13                           บริโภคการเล่นเกมส์  Consumption
# ...

# %%
df2.to_excel("interest_type.xlsx")
df3.to_excel("consump_type.xlsx")
